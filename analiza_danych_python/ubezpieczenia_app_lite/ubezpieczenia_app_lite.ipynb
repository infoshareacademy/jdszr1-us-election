# %%
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import funkcje2016 as f


path = os.path.abspath("dane")
rate2016_df = pd.read_csv(os.path.join(path, "Rate2016.csv"))
network_df = pd.read_csv(os.path.join(path, "Network.csv"))
pa_df = pd.read_csv(os.path.join(path, "PlanAttributes.csv"))
bcs_df = pd.read_csv(os.path.join(path, "BenefitsCostSharing.csv"))
# Out:
# /home/joanna/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (0,7,8,9,10,11,12,13,14,15,18,19,20,22,23,24,25,26,27,28,29,31,32,33,34,39,40,41,42,66,67,68,70,71,72,75,76,77,79,80,81,82,84,85,86,88,89,90,92,93,94,96,97,98,136,137,138,140,141,142,145,146,147,150,151,152,154,155,156,158,159,160,162,163,164,166,167,168) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /home/joanna/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (3,6,9,10,16,17,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
f.best_healthcare(network_df, pa_df, rate2016_df, bcs_df)
# Out:
# Aplikacja służąca do wyboru ubezpieczenia zdrowotnego
#
# W pierwszym kroku zadamy Ci kilka pytań dotyczących Twoich preferencji odnośnie ubezpieczenia:
#
# Lista state codes:
# ['AK', 'AL', 'AR', 'AZ', 'DE', 'FL', 'GA', 'HI', 'IA', 'IL', 'IN', 'KS', 'LA', 'ME', 'MI', 'MO', 'MS', 'MT', 'NC', 'ND', 'NE', 'NH', 'NJ', 'NM', 'NV', 'OH', 'OK', 'OR', 'PA', 'SC', 'SD', 'TN', 'TX', 'UT', 'VA', 'WI', 'WV', 'WY']
#
# Podaj kod stanu, w którym chcesz się ubezpieczyć:FL
# Czy chcesz się ubezpieczyć z rodziną? y/n:n
#
# Podaj swój wiek:34
#
# Poniżej znajdują się wybrane dla Ciebie plany ubezpieczeniowe:
#    IndividualRate          PlanId  \
# 0            6.60  85019FL0010001
# 1          268.68  35783FL1160015
# 2          317.17  27357FL1820011
# 3          381.66  27357FL1860020
#
#                                    PlanMarketingName  \
# 0  LIBERTY Dental Plan FL Pediatric Low with Adul...
# 1               Humana Connect Bronze 4850/6350 Plan
# 2                      HF Silver HMO Select 100 1046
# 3                  Florida Hospital Gold HMO 50 5141
#
#                  NetworkName
# 0       Florida Exchange CAP
# 1  South Florida HUMx (HMOx)
# 2           Enhanced Network
# 3  Health First Health Plans
# W poniższych tabelach zaprezentowane zostały benefity, dla każdego z czterech powyższych planów
#        PlanIdBase                      BenefitName ExtraCharge LimitQty  \
# 0  85019FL0010001        Major Dental Care - Child          0%      N/A
# 1  85019FL0010001  Routine Dental Services (Adult)          0%      N/A
# 2  85019FL0010001        Basic Dental Care - Adult          0%      N/A
# 3  85019FL0010001        Basic Dental Care - Child          0%      N/A
# 4  85019FL0010001     Dental Check-Up for Children          0%        2
#
#            LimitUnit
# 0                N/A
# 1                N/A
# 2                N/A
# 3                N/A
# 4  Visit(s) per Year
#        PlanIdBase                                BenefitName  \
# 0  35783FL1160015                          Dental Anesthesia
# 1  35783FL1160015                          Accidental Dental
# 2  35783FL1160015                          Dental Anesthesia
# 3  35783FL1160015  Accidental Dental - Treatment days 63-365
# 4  35783FL1160015                          Accidental Dental
#
#                         ExtraCharge LimitQty LimitUnit
# 0  20% Coinsurance after deductible      N/A       N/A
# 1  20% Coinsurance after deductible      N/A       N/A
# 2  20% Coinsurance after deductible      N/A       N/A
# 3  20% Coinsurance after deductible      N/A       N/A
# 4  20% Coinsurance after deductible      N/A       N/A
#        PlanIdBase                   BenefitName  \
# 0  27357FL1820011             Dental Anesthesia
# 1  27357FL1820011  Dental Check-Up for Children
# 2  27357FL1820011     Basic Dental Care - Child
# 3  27357FL1820011             Dental Anesthesia
# 4  27357FL1820011  Dental Check-Up for Children
#
#                        ExtraCharge LimitQty              LimitUnit
# 0  0% Coinsurance after deductible      N/A                    N/A
# 1                        No Charge        1  Visit(s) per 6 Months
# 2                        No Charge      N/A                    N/A
# 3  0% Coinsurance after deductible      N/A                    N/A
# 4                        No Charge        1  Visit(s) per 6 Months
#        PlanIdBase                   BenefitName  \
# 0  27357FL1860020     Major Dental Care - Child
# 1  27357FL1860020             Accidental Dental
# 2  27357FL1860020     Basic Dental Care - Child
# 3  27357FL1860020             Dental Anesthesia
# 4  27357FL1860020  Dental Check-Up for Children
#
#                         ExtraCharge LimitQty              LimitUnit
# 0                         No Charge      N/A                    N/A
# 1  50% Coinsurance after deductible      N/A                    N/A
# 2                         No Charge      N/A                    N/A
# 3  50% Coinsurance after deductible      N/A                    N/A
# 4                         No Charge        1  Visit(s) per 6 Months
