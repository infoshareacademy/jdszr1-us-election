# %%
import pandas as pd
import os
import numpy as np
import funkcje as f
import funkcja_choose_benefit as bc

path = os.path.abspath("dane")
rate_df = pd.read_csv(os.path.join(path, "Rate2016.csv"))
network_df = pd.read_csv(os.path.join(path, "Network2016.csv"))
pa_df = pd.read_csv(os.path.join(path, "PlanAttributes2016.csv"))
df_bcs = pd.read_csv(os.path.join(path, "BenefitsCostSharing2016.csv"))
# Out:
# /home/joanna/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (7,10,11,12,32,33,34,40,41,42,149,151,152,153) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /home/joanna/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (3,6,9,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
print("Aplikacja służąca do wyboru ubezpieczenia zdrowotnego\n")
print("W pierwszym kroku zadamy Ci kilka pytań dotyczących Twoich preferencji dotyczących ubezpieczenia:")


state_code = f.choose_state()
age,option = f.get_data()

plan_output = f.show_result(state_code, age, option, network_df, pa_df, rate_df) 
if plan_output.empty:
    print("\nNiestety nie dyspozujemy planem ubezpieczeniowym dla podanych kruteriów")
else:
    print("\nPoniżej znajdują się wybrane dla Ciebie plany ubezpieczeniowe:")
plan_output
# Out:
# Aplikacja służąca do wyboru ubezpieczenia zdrowotnego
#
# W pierwszym kroku zadamy Ci kilka pytań dotyczących Twoich preferencji dotyczących ubezpieczenia:
#
# Lista state codes:
# ['AK', 'AL', 'AR', 'AZ', 'DE', 'FL', 'GA', 'HI', 'IA', 'IL', 'IN', 'KS', 'LA', 'ME', 'MI', 'MO', 'MS', 'MT', 'NC', 'ND', 'NE', 'NH', 'NJ', 'NM', 'NV', 'OH', 'OK', 'OR', 'PA', 'SC', 'SD', 'TN', 'TX', 'UT', 'VA', 'WI', 'WV', 'WY']
#
# Podaj kod stanu, w którym chcesz się ubezpieczyć:Fl
#
# Niepoprawny state code. Wybierz z listy.
# Podaj kod stanu, w którym chcesz się ubezpieczyć:FL
# Czy chcesz się ubezpieczyć z rodziną? y/n:n
#
# Podaj swój wiek:34
#
# Poniżej znajdują się wybrane dla Ciebie plany ubezpieczeniowe:
#    IndividualRate          PlanId  \
# 0            6.60  85019FL0010001
# 1          274.08  27357FL1820023
# 2          318.44  27357FL1850043
# 3          379.58  27357FL1880009
#
#                                    PlanMarketingName           NetworkName
# 0  LIBERTY Dental Plan FL Pediatric Low with Adul...  Florida Exchange CAP
# 1                    Health First Bronze HMO 90 1254      FHCA Small Group
# 2                    Health First Silver POS 50 5317      FHCA Small Group
# 3                  Florida Hospital Gold HMO 70 1512      FHCA Small Group

# %%
print("W poniższej tabeli są zaprezentowane benefity, dla każdego z czterech powyższych planów")
bc.choose_benefit(plan_output, df_bcs)
# Out:
# W poniższej tabeli są zaprezentowane benefity, dla każdego z czterech powyższych planów
#         PlanIdBase                   BenefitName  \
# 0   27357FL1820023     Basic Dental Care - Child
# 1   27357FL1820023     Major Dental Care - Child
# 2   27357FL1820023             Accidental Dental
# 3   27357FL1820023             Dental Anesthesia
# 4   27357FL1820023  Dental Check-Up for Children
# ..             ...                           ...
# 57  85019FL0010001  Dental Check-Up for Children
# 58  85019FL0010001     Basic Dental Care - Child
# 59  85019FL0010001     Major Dental Care - Child
# 60  85019FL0010001     Basic Dental Care - Adult
# 61  85019FL0010001     Major Dental Care - Adult
#
#                          ExtraCharge LimitQty              LimitUnit
# 0                     Not Applicable      N/A                    N/A
# 1                     Not Applicable      N/A                    N/A
# 2   10% Coinsurance after deductible      N/A                    N/A
# 3   10% Coinsurance after deductible      N/A                    N/A
# 4                     Not Applicable        1  Visit(s) per 6 Months
# ..                               ...      ...                    ...
# 57                    Not Applicable        2  Visit(s) per 6 Months
# 58                    Not Applicable      N/A                    N/A
# 59                    Not Applicable      N/A                    N/A
# 60                    Not Applicable      N/A                    N/A
# 61                    Not Applicable      N/A                    N/A
#
# [62 rows x 5 columns]
