# %%
import pandas as pd
import os
import numpy as np
import funkcje as f
import funkcja_choose_benefit as bc

path = os.path.abspath("dane")
rate_df = pd.read_csv(os.path.join(path, "Rate2016.csv"))
network_df = pd.read_csv(os.path.join(path, "Network2016.csv"))
pa_df = pd.read_csv(os.path.join(path, "PlanAttributes2016.csv"))
df_bcs = pd.read_csv(os.path.join(path, "BenefitsCostSharing2016.csv"))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (7,10,11,12,32,33,34,40,41,42,149,151,152,153) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (3,6,9,16) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
state_code = f.pobierz_state()
age,opcja = f.pobierz_dane()

plan_output = f.pokaz_wynik(state_code, age, opcja, network_df, pa_df, rate_df) 
plan_output
# Out:
# Lista state codes:
# ['AK', 'AL', 'AR', 'AZ', 'DE', 'FL', 'GA', 'HI', 'IA', 'IL', 'IN', 'KS', 'LA', 'ME', 'MI', 'MO', 'MS', 'MT', 'NC', 'ND', 'NE', 'NH', 'NJ', 'NM', 'NV', 'OH', 'OK', 'OR', 'PA', 'SC', 'SD', 'TN', 'TX', 'UT', 'VA', 'WI', 'WV', 'WY']
# State code:AK
# Czy chcesz się ubezpieczyć z rodziną? y/n:n
# Wiek:21
#    IndividualRate          PlanId  \
# 0           25.84  47904AK0070002
# 1          458.00  73836AK0850002
# 2          531.00  38344AK0570001
# 3          633.00  38344AK0570002
#
#                                    PlanMarketingName          NetworkName
# 0         Delta Dental Individual PPO, EHB Certified   Renaissance Dental
# 1                   Moda Health Providence Be Secure  Endeavor Providence
# 2  Blue Cross Blue Shield Plus 5250 HSA HIGH, a M...         HeritagePlus
# 3  Blue Cross Blue Shield Plus 3000 HSA HIGH, a M...         HeritagePlus

# %%
bc.choose_benefit(plan_output, df_bcs)
# Out:
#         PlanIdBase                      BenefitName  \
# 0   47904AK0070002  Routine Dental Services (Adult)
# 1   47904AK0070002     Dental Check-Up for Children
# 2   47904AK0070002        Basic Dental Care - Child
# 3   47904AK0070002        Major Dental Care - Child
# 4   47904AK0070002        Basic Dental Care - Adult
# 5   47904AK0070002        Major Dental Care - Adult
# 6   47904AK0070002                Accidental Dental
# 7   73836AK0850002     Dental Check-Up for Children
# 8   73836AK0850002        Basic Dental Care - Child
# 9   73836AK0850002        Major Dental Care - Child
# 10  73836AK0850002                Accidental Dental
# 11  73836AK0850002        Major Dental Care - Child
# 12  73836AK0850002                Accidental Dental
# 13  73836AK0850002     Dental Check-Up for Children
# 14  73836AK0850002        Basic Dental Care - Child
# 15  73836AK0850002        Major Dental Care - Child
# 16  73836AK0850002                Accidental Dental
# ...
